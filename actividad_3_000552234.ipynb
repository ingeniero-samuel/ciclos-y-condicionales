# %% [markdown]
# <a href="https://colab.research.google.com/github/ingeniero-samuel/ciclos-y-condicionales/blob/main/actividad_3_000552234.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Examen de programacion
# nombre: samuel david martinez gomez<br>
# ID:00055234<br>
# 22/03/24

# %% [markdown]
# <h3>Analisis de filtracion de señales:</h3>
#
# formula: funcion de densidad de probabilidad de la campana de gauss<br>
# o=300Hz<br>
# u=1000Hz<br>
# PI=3.1416<br>
# e=2,71828<br>
# fdp = (1/(o*sqrt(2*PI))*e^(-1/2*((x-u)/o)^2)<br>
# <br>
# input x (frecuencia de la señal)<br>
# desde cero hasta la cantidad deseada
#
# result(determinar si esta pasa por el filtro o es bloqueada)<br>
#
#    si la probabilidad es mayor a 30%:<br>
# 	   la señal pasa<br>
#    si no: <br>
# 	   es bloqueada<br>

# %% [markdown]
#     program filtracion_de_señales
#
#     Inicio
#
#     Declare float fdp, porcent,
#     constant U=1000, O=300, PI = 3.1416, e = 2.71828
#
#     Display "ingrese la frecuencia de la señal hasta dpnde usted desee: "
#     Input n
#
#     porcent = 0
#     x=0
#
#     for i until n to do:
#       x+=1
#       fdp = (1 / (o * sqrt(2 * PI))) * e *(-1/2 * ((x - u) / o)* 2)
#       porcent = porcent + fdp
#       porcent_total = porcent
#     end for
#
#     display porcent_total
#
#     if porcent_total >0.30 then:
#       Display "la señal pasa"
#     else:
#       Display "esta bloqueada"
#
#     Stop

# %%
n=int(input("ingrese la frecuencia de la señal hasta donde usted desee: "))
o, u , PI, e= 300, 1000, 3.1416, 2.71828

porcent = 0
x=0

for i in range(n):
  x+=1
  fdp = (1 / (o * math.sqrt(2 * PI))) * e ** (-1/2 * ((x - u) / o) ** 2)
  porcent += fdp
  porcent_total = porcent
print(f"la densidad de probabilidad de filtracion de señal es: {porcent_total}")

if porcent_total >0.30:
  print("por ende la señal si pasa")
else:
  print("por ende esta se encuentra bloqueada")
# Out:
# ingrese la frecuencia de la señal hasta donde usted desee: 842
# la densidad de probabilidad de filtracion de señal es: 0.29935968573012833
# por ende esta se encuentra bloqueada

# %% [markdown]
#  Pregunta: ¿para qué valor de frecuencia la señal deja de ser bloqueada?<br>
#  la frecuencia deja se ser bloqueada desde 843

# %% [markdown]
# ![Diagrama en blanco (2).png](data:image/png;base64,...)

# %% [markdown]
# ```
# prueba 1:
# inizializar programa
# definir fdp, porcent como float
# constantes U=1000, O=300, PI = 3.1416, e = 2.71828
# valor ingresado por el usuario:
# 832
# la señal "832" esta bloqueada
#
# prueba 2:
# inizializar programa
# definir fdp, porcent como float
# constantes U=1000, O=300, PI = 3.1416, e = 2.71828
# valor ingresado por el usuario:
# 844
# la señal "844" pasa
#
# prueba 3:
# inizializar programa
# definir fdp, porcent como float
# constantes U=1000, O=300, PI = 3.1416, e = 2.71828
# valor ingresado por el usuario:
# 20
# la señal "20" esta bloqueada
#
# ```
